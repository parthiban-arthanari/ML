# %%
import os
import pandas as pd
from pandasai import Agent

# %%
sales_by_country = pd.DataFrame({
    "country": ["United States", "United Kingdom", "France", "Germany", "Italy", "Spain", "Canada", "Australia", "Japan", "China"],
    "sales": [5000, 3200, 2900, 4100, 2300, 2100, 2500, 2600, 4500, 7000]
})

# %%
os.environ["PANDASAI_API_KEY"] = "$2a$10$TH0bSTzaTf9GJTqSle/gx.JiiW7IDDzohzjrQ8YrFPn1MV6j.qks."

# %%
agent = Agent(sales_by_country)
agent.chat('Which are the top 5 countries by sales?')
# Out:
# 'The top 5 countries by sales are: China, United States, Japan, Germany, United Kingdom.'

# %%
agent.chat(
    "What is the total sales for the top 3 countries by sales?"
)
# Out:
# 'The total sales for the top 3 countries by sales is 36200.'

# %%
agent.chat(
    "Plot the histogram of countries showing for each the gdp, using different colors for each bar",
)
# Out:
# '/Users/parthi/Projects/ML/sql-coder/pandas-ai/exports/charts/temp_chart.png'

# %%
agent.chat("plot pie chart for this data set")
# Out:
# '/Users/parthi/Projects/ML/sql-coder/pandas-ai/exports/charts/temp_chart.png'

# %%
agent.chat("draw scatter plot for given data set")
# Out:
# Traceback (most recent call last):
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/generate_chat_pipeline.py", line 307, in run
#     output = (self.code_generation_pipeline | self.code_execution_pipeline).run(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/pipeline.py", line 137, in run
#     raise e
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/code_execution.py", line 125, in execute
#     code_to_run = self._retry_run_code(
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/code_execution.py", line 346, in _retry_run_code
#     return self.on_retry(code, e)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/generate_chat_pipeline.py", line 149, in on_code_retry
#     return self.code_exec_error_pipeline.run(correction_input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/error_correction_pipeline/error_correction_pipeline.py", line 48, in run
#     return self.pipeline.run(input)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/pipeline.py", line 137, in run
#     raise e
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/pipelines/chat/code_generator.py", line 33, in execute
#     code = pipeline_context.config.llm.generate_code(input, pipeline_context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/llm/base.py", line 201, in generate_code
#     return self._extract_code(response)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/parthi/.pyenv/versions/3.12.0/envs/open-ai/lib/python3.12/site-packages/pandasai/llm/base.py", line 121, in _extract_code
#     raise NoCodeFoundError("No code found in the response")
# pandasai.exceptions.NoCodeFoundError: No code found in the response
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nNo code found in the response\n'
